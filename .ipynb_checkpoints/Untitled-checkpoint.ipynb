# %%
import pandas as pd

# %%
df = pd.read_csv("Sector_L_Bahria.csv", sep =",")

# %%
df
# Out:
#     Sector       Name  CRIM      PLT SOUTH    HGW  W120 F120   W80 F80  ...  \
# 0        L  St-59(UP)   NaN  35 x 70     Y  12300  1800    N   130   N  ...
# 1        L  St-59(DN)   NaN  35 x 70     N  12600  2100    N    73   N  ...
# 2        L   St-58(S)   NaN  30 x 40     Y  12200  1700    N   350   N  ...
# 3        L   St-58(N)   NaN  30 x 60     N  12200  1700    N   350   N  ...
# 4        L   St-57(S)   NaN  30 x 60     Y  12200  1700    N   290   N  ...
# ..     ...        ...   ...      ...   ...    ...   ...  ...   ...  ..  ...
# 126      L    St-3(N)   NaN  35 x 70     N  12300  1500    N   550   N  ...
# 127      L    St-2(S)   NaN  35 x 70     Y  12200  1500    Y   500   N  ...
# 128      L    St-2(N)   NaN  35 x 70     N  12000  1000    N  1000   N  ...
# 129      L      St-2A   NaN  35 x 70     N  11900  1100    N   850   N  ...
# 130      L       St-1   NaN  35 x 70     N  12200  1700    N   450   N  ...
#
# ...
